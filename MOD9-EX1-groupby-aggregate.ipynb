# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
sinasc_raw = pd.read_csv('SINASC_RO_2019.csv')
sinasc_raw.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1        2        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2        3        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3        4        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4        5        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
#
#    munResLat munResLon  munResAlt  munResArea
# 0  -11.93554 -61.99982      338.0    7067.025
# 1  -11.93554 -61.99982      338.0    7067.025
# 2  -11.93554 -61.99982      338.0    7067.025
# 3  -12.13178 -61.85308      397.0    3958.273
# 4  -11.93554 -61.99982      338.0    7067.025
#
# [5 rows x 69 columns]

# %% [markdown]
# # Tarefa 1

# %%
sinasc_raw.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
#        'munResUf', 'munResLat', 'munResLon', 'munResAlt', 'munResArea'],
#       dtype='object')

# %%
df.shape
# Out:
# (27028, 3)

# %% [markdown]
# ### 1. Idade media das mães e dos pais por município (coluna munResNome)

# %%
# crio um dataframe só com as colunas que serão utilizadas

df = sinasc_raw[ ['munResNome', 'IDADEMAE', 'IDADEPAI'] ]
df.head()
# Out:
#                 munResNome  IDADEMAE  IDADEPAI
# 0    Alta Floresta D'Oeste        19      26.0
# 1    Alta Floresta D'Oeste        29      24.0
# 2    Alta Floresta D'Oeste        37      32.0
# 3  Alto Alegre dos Parecis        30      24.0
# 4    Alta Floresta D'Oeste        30      27.0

# %%
df.isnull().sum()
# Out:
# munResNome        0
# IDADEMAE          0
# IDADEPAI      19421
# dtype: int64

# %%
# tratar os NaN

df.loc[ df['IDADEPAI'].isnull() , 'IDADEPAI' ] = df['IDADEPAI'].median()

# %%
df.groupby('munResNome').mean()
# Out:
#                             IDADEMAE   IDADEPAI
# munResNome
# Alta Floresta D'Oeste      25.991826  29.621253
# Alto Alegre dos Parecis    24.844156  29.285714
# Alto Paraíso               24.960177  29.969027
# Alvorada D'Oeste           25.770732  30.380488
# Ariquemes                  25.607866  30.021400
# Buritis                    25.559177  30.089194
# Cabixi                     26.037500  30.325000
# Cacaulândia                25.546667  30.506667
# Cacoal                     26.890102  30.855895
# Campo Novo de Rondônia     24.825301  30.090361
# Candeias do Jamari         25.243323  29.994065
# Castanheiras               27.281250  30.343750
# Cerejeiras                 27.240506  30.502110
# Chupinguaia                25.333333  29.938272
# Colorado do Oeste          27.602804  30.630841
# Corumbiara                 24.716535  30.330709
# Costa Marques              24.412017  30.115880
# Cujubim                    24.482927  30.068293
# Espigão D'Oeste            26.093333  30.846667
# Governador Jorge Teixeira  24.401786  29.937500
# Guajará-Mirim              25.462228  30.010243
# Itapuã do Oeste            26.064220  30.917431
# Jaru                       25.982974  30.354143
# Ji-Paraná                  26.361137  30.537580
# Machadinho D'Oeste         25.480000  30.276000
# Ministro Andreazza         27.904762  33.345238
# Mirante da Serra           26.304878  31.103659
# Monte Negro                25.648241  30.658291
# Município ignorado - RO    24.000000  22.000000
# Nova Brasilândia D'Oeste   26.222222  30.095785
# Nova Mamoré                25.326389  30.152778
# Nova União                 26.894231  30.923077
# Novo Horizonte do Oeste    26.938776  31.377551
# Ouro Preto do Oeste        26.375594  30.729002
# Parecis                    26.454545  32.136364
# Pimenta Bueno              25.199675  29.785714
# Pimenteiras do Oeste       25.075000  30.700000
# Porto Velho                26.312670  30.187389
# Presidente Médici          25.796053  30.098684
# Primavera de Rondônia      27.023256  31.581395
# Rio Crespo                 26.660000  29.960000
# Rolim de Moura             26.600863  30.324703
# Santa Luzia D'Oeste        26.121212  30.646465
# Seringueiras               24.910714  30.101190
# São Felipe D'Oeste         26.481481  31.240741
# São Francisco do Guaporé   25.660066  30.194719
# São Miguel do Guaporé      25.926346  30.611898
# Teixeirópolis              26.031250  31.031250
# Theobroma                  25.536082  30.010309
# Urupá                      26.688235  30.664706
# Vale do Anari              26.096774  30.645161
# Vale do Paraíso            25.679012  29.987654
# Vilhena                    26.433962  30.444025

# %% [markdown]
# ### 2. Peso médio dos bebes por sexo que nasceram no dia do seu aniversário por faixas de escolaridade mae
# Ex: Você, aluna(o), nasceu no dia 10/01, então você precisa filtrar o conjunto de dados nessa data e calcular o peso médio dos bebês de cada sexo por faixa de escolaridade da mãe.

# %%
sinasc_raw.columns

df = sinasc_raw[ ['PESO', 'SEXO', 'ESCMAE', 'DTNASC'] ]

df.head()
# Out:
#    PESO       SEXO           ESCMAE      DTNASC
# 0  3685  Masculino      8 a 11 anos  2019-02-19
# 1  3055   Feminino      8 a 11 anos  2019-02-21
# 2  3460   Feminino      8 a 11 anos  2019-02-25
# 3  2982   Feminino  12 anos ou mais  2019-03-20
# 4  3310   Feminino      8 a 11 anos  2019-03-23

# %%
df.isnull().sum()
# Out:
# PESO        0
# SEXO        4
# ESCMAE    312
# DTNASC      0
# dtype: int64

# %%
# neste caso como tempos poucos NaN, serão dropados
df = df.copy()

df.dropna(inplace=True)

# %%
df[ df['DTNASC'] == '2019-05-07' ].groupby(by = ['ESCMAE', 'SEXO']).mean(numeric_only=True)
# Out:
#                                   PESO
# ESCMAE          SEXO
# 1 a 3 anos      Feminino   2945.000000
# 12 anos ou mais Feminino   3122.700000
#                 Masculino  3330.384615
# 4 a 7 anos      Feminino   3350.000000
#                 Masculino  3184.285714
# 8 a 11 anos     Feminino   2934.062500
#                 Masculino  3455.454545

# %% [markdown]
# ### 3. Qual o municipio que nasceu menos bebe em 2019?
#     - qual a idade media, maxima, minima das maes nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
df = sinasc_raw[ ['munResNome', 'IDADEPAI', 'IDADEMAE'] ].copy()

df.head()
# Out:
#                 munResNome  IDADEPAI  IDADEMAE
# 0    Alta Floresta D'Oeste      26.0        19
# 1    Alta Floresta D'Oeste      24.0        29
# 2    Alta Floresta D'Oeste      32.0        37
# 3  Alto Alegre dos Parecis      24.0        30
# 4    Alta Floresta D'Oeste      27.0        30

# %%
df.isnull().sum()
# Out:
# munResNome        0
# IDADEPAI      19421
# IDADEMAE          0
# dtype: int64

# %%
# Troca os NaN pela mediana
df['IDADEPAI'].fillna(value = df['IDADEPAI'].median(), inplace=True)

# %%
# Qual o municipio que nasceu menos bebe em 2019?

df['munResNome'].value_counts(ascending=True).head()

# Castanheiras
# Out:
# Município ignorado - RO     1
# Castanheiras               32
# Pimenteiras do Oeste       40
# Primavera de Rondônia      43
# Parecis                    44
# Name: munResNome, dtype: int64

# %%
# Idade média, maxima e mínima dos pais e mães desse municipio

df[ df['munResNome'] == 'Castanheiras' ].aggregate( 
    {
        'IDADEPAI': ['mean', 'max', 'min'], 
        'IDADEMAE': ['mean', 'max', 'min'], 
    } )
# Out:
#       IDADEPAI  IDADEMAE
# mean  30.34375  27.28125
# max   43.00000  39.00000
# min   17.00000  17.00000

# %% [markdown]
# ### 4. Qual o municipio que nasceu mais bebe no mês de março?
#     - qual a quantidade de filhos vivos media, maxima, minima nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
df = sinasc_raw[ ['munResNome', 'IDADEPAI', 'IDADEMAE', 'DTNASC', 'QTDFILVIVO'] ].copy()
df.head()
# Out:
#                 munResNome  IDADEPAI  IDADEMAE      DTNASC  QTDFILVIVO
# 0    Alta Floresta D'Oeste      26.0        19  2019-02-19         0.0
# 1    Alta Floresta D'Oeste      24.0        29  2019-02-21         1.0
# 2    Alta Floresta D'Oeste      32.0        37  2019-02-25         2.0
# 3  Alto Alegre dos Parecis      24.0        30  2019-03-20         0.0
# 4    Alta Floresta D'Oeste      27.0        30  2019-03-23         1.0

# %%
df.isnull().sum()
# Out:
# munResNome        0
# IDADEPAI      19421
# IDADEMAE          0
# DTNASC            0
# QTDFILVIVO     1573
# dtype: int64

# %%
# Muitos pais sem a idade registrada, não pode dropar então substitui pela mediada
df['IDADEPAI'].fillna(value = df['IDADEPAI'].median(), inplace=True)

# Poucos casos de qtde filhos vivos não registrados, então dropa essas linhas
df.dropna(inplace=True)

df.isnull().sum()
# Out:
# munResNome    0
# IDADEPAI      0
# IDADEMAE      0
# DTNASC        0
# QTDFILVIVO    0
# dtype: int64

# %%
# converter a coluna pra tipo data
df['DTNASC'] = pd.to_datetime(df['DTNASC'])

# %%
# Qual o municipio que nasceu mais bebe no mês de março? = Porto Velho

df.loc[ df['DTNASC'].dt.month == 3, 'munResNome' ].value_counts().head()
# Out:
# Porto Velho    627
# Ji-Paraná      187
# Vilhena        147
# Ariquemes      139
# Cacoal         132
# Name: munResNome, dtype: int64

# %%
# qual a quantidade de filhos vivos media, maxima, minima nesse municipio?

df[ df['munResNome'] == 'Porto Velho' ].aggregate( {'QTDFILVIVO': ['mean', 'max', 'min']} )
# Out:
#       QTDFILVIVO
# mean    1.167236
# max    12.000000
# min     0.000000

# %%
# qual a idade media, maxima, minima dos pais nesse municipio?

df[ df['munResNome'] == 'Porto Velho' ].aggregate({
    'IDADEPAI': ['mean', 'max', 'min'],
    'IDADEMAE': ['mean', 'max', 'min']
})
# Out:
#        IDADEPAI   IDADEMAE
# mean  30.208089  26.738625
# max   65.000000  45.000000
# min   16.000000  12.000000

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados. Algo que você julgue relevante e novo pra você.

# %% [markdown]
# Exemplo:
# - Ah, descobri que a idade mediana das mulheres que deram a luz no ano de 2019 dos municipios x é maior que y.

# %% [markdown]
# Aparantemente, sempre a idade min, max e média do pai é maior do que a da mãe. Em todos os municípios levantados pode-se nota este fenomeno.

# %%
sinasc_raw.dtypes
# Out:
# ORIGEM          int64
# CODESTAB      float64
# CODMUNNASC      int64
# LOCNASC         int64
# IDADEMAE        int64
#                ...
# munResUf       object
# munResLat     float64
# munResLon     float64
# munResAlt     float64
# munResArea    float64
# Length: 69, dtype: object

# %%
sinasc_raw.select_dtypes(exclude=['int64','float64'])
# Out:
#                 ESCMAE         GESTACAO GRAVIDEZ    PARTO      DTNASC  \
# 0          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-19
# 1          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-21
# 2          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-25
# 3      12 anos ou mais  37 a 41 semanas    Única  Cesáreo  2019-03-20
# 4          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-03-23
# ...                ...              ...      ...      ...         ...
# 27023  12 anos ou mais  32 a 36 semanas    Única  Cesáreo  2019-12-13
# 27024      8 a 11 anos  37 a 41 semanas    Única  Vaginal  2019-10-04
# 27025      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-08-02
# 27026      8 a 11 anos  32 a 36 semanas    Única  Vaginal  2019-12-23
# 27027      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-12-27
#
#             SEXO RACACOR  DTCADASTRO CODANOMAL VERSAOSIST   DTRECEBIM  \
# 0      Masculino  Branca  2019-03-08       NaN     3.2.01  2019-03-08
# 1       Feminino  Branca  2019-03-08       NaN     3.2.01  2019-03-08
# 2       Feminino  Branca  2019-03-08       NaN     3.2.01  2019-03-08
# 3       Feminino   Parda  2019-04-03       NaN     3.2.01  2019-04-09
# 4       Feminino   Parda  2019-04-03       NaN     3.2.01  2019-04-09
# ...          ...     ...         ...       ...        ...         ...
# 27023  Masculino  Branca  2020-09-28       NaN     3.2.01  2020-10-13
# 27024  Masculino  Branca  2019-10-16       NaN     3.2.01  2019-10-21
# 27025  Masculino   Parda  2019-08-07       NaN     3.2.00  2019-08-07
# 27026  Masculino   Parda  2020-01-07       NaN     3.2.00  2020-01-07
# 27027  Masculino   Parda  2020-10-15       NaN     3.2.01  2020-10-16
#
#       munResStatus munResTipo               munResNome  munResUf
# 0            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3            ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...            ...        ...                      ...       ...
# 27023        ATIVO      MUNIC                  Vilhena  Rondônia
# 27024        ATIVO      MUNIC              Chupinguaia  Rondônia
# 27025        ATIVO      MUNIC                  Vilhena  Rondônia
# 27026        ATIVO      MUNIC                  Vilhena  Rondônia
# 27027        ATIVO      MUNIC  Novo Horizonte do Oeste  Rondônia
#
# [27028 rows x 15 columns]

# %%
sinasc_raw.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
#        'munResUf', 'munResLat', 'munResLon', 'munResAlt', 'munResArea'],
#       dtype='object')
